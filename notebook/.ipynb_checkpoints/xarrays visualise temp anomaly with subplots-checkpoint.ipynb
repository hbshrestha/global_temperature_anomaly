# %% [markdown]
# GISTEMP full data: https://data.giss.nasa.gov/pub/gistemp/
#
# and select:    gistemp1200_GHCNv4_ERSSTv5.nc.gz

# %% [markdown]
# https://towardsdatascience.com/visualizing-climate-change-data-with-python-74ea5bac8756

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
import xarray as xr
import numpy as np

import xarray as xr
file = "../data/gistemp1200_GHCNv4_ERSSTv5.nc"
xr_df = xr.open_dataset(file)
xr_df
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 90, lon: 180, time: 1709, nv: 2)
# Coordinates:
#   * lat          (lat) float32 -89.0 -87.0 -85.0 -83.0 ... 83.0 85.0 87.0 89.0
#   * lon          (lon) float32 -179.0 -177.0 -175.0 -173.0 ... 175.0 177.0 179.0
#   * time         (time) datetime64[ns] 1880-01-15 1880-02-15 ... 2022-05-15
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds    (time, nv) datetime64[ns] ...
#     tempanomaly  (time, lat, lon) float32 ...
# Attributes:
#     title:        GISTEMP Surface Temperature Analysis
#     institution:  NASA Goddard Institute for Space Studies
#     source:       http://data.giss.nasa.gov/gistemp/
#     Conventions:  CF-1.6
#     history:      Created 2022-06-10 10:13:14 by SBBX_to_nc 2.0 - ILAND=1200,...

# %%
anomaly = xr_df["tempanomaly"]
anomaly
# Out:
# <xarray.DataArray 'tempanomaly' (time: 1709, lat: 90, lon: 180)>
# [27685800 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float32 -179.0 -177.0 -175.0 -173.0 ... 175.0 177.0 179.0
#   * time     (time) datetime64[ns] 1880-01-15 1880-02-15 ... 2022-05-15
# Attributes:
#     long_name:     Surface temperature anomaly
#     units:         K
#     cell_methods:  time: mean

# %%
xr_df_annual = xr_df.resample(time = "Y").mean()

anomaly = xr_df_annual["tempanomaly"]

anomaly.isel(time = -1)
# Out:
# <xarray.DataArray 'tempanomaly' (lat: 90, lon: 180)>
# array([[0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        [0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        [0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        ...,
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001],
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001],
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001]], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2022-12-31
#   * lat      (lat) float32 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float32 -179.0 -177.0 -175.0 -173.0 ... 175.0 177.0 179.0

# %%
#Creating a static image of the global temperature anomaly for a given year.
cbar_kwargs = {
    'orientation':'horizontal',
    'fraction': 0.045,
    'pad': 0.01,
    'extend':'both'
}

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(1,1,1, projection = ccrs.PlateCarree())
ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '10m'),
                       facecolor='none', edgecolor='black')
ax.set_extent([-150, 150, -55, 85])

i=-1
date =  pd.to_datetime(anomaly.isel(time=i)['time'].values)

anomaly_value = round(float(anomaly.isel(time = -1).mean().values), 2)

ax.set_title("Temperature Anomaly in "+ str(date.year) + f": +{anomaly_value} [°C] relative to 1951-1980 Mean")
anomaly.isel(time=i).plot.imshow(ax=ax, add_labels=False, add_colorbar=True,
               vmin=-4, vmax=4, cmap='coolwarm',
               cbar_kwargs=cbar_kwargs, interpolation='bicubic')

# %%
#Creating a static image of the european temperature anomaly for a given year.
cbar_kwargs = {
    'orientation':'horizontal',
    'fraction': 0.048,
    'pad': 0.01,
    'extend':'both'
}

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,1,1, projection = ccrs.PlateCarree())
ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '10m'),
                       facecolor='none', edgecolor='black')

ax.set_extent([60, 100, 0, 40])

i=-1
date =  pd.to_datetime(anomaly.isel(time=i)['time'].values)
ax.set_title("Temperature Anomaly in "+ str(date.year) + " [°C]")
xr.plot.imshow(anomaly.isel(time=i), ax=ax, add_labels=False,
                   vmin=-4, vmax=4, cmap='coolwarm', 
                   cbar_kwargs=cbar_kwargs, interpolation='bicubic')

plt.show()

# %%
anomaly.isel(time = -1)
# Out:
# <xarray.DataArray 'tempanomaly' (lat: 90, lon: 180)>
# array([[0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        [0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        [0.65     , 0.65     , 0.65     , ..., 0.65     , 0.65     ,
#         0.65     ],
#        ...,
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001],
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001],
#        [3.6200001, 3.6200001, 3.6200001, ..., 3.6200001, 3.6200001,
#         3.6200001]], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2022-12-31
#   * lat      (lat) float32 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float32 -179.0 -177.0 -175.0 -173.0 ... 175.0 177.0 179.0

# %%
anomaly.loc["2021-12-31"]
# Out:
# <xarray.DataArray 'tempanomaly' (lat: 90, lon: 180)>
# array([[-1.0933334, -1.0933334, -1.0933334, ..., -1.0933334, -1.0933334,
#         -1.0933334],
#        [-1.0933334, -1.0933334, -1.0933334, ..., -1.0933334, -1.0933334,
#         -1.0933334],
#        [-1.0933334, -1.0933334, -1.0933334, ..., -1.0933334, -1.0933334,
#         -1.0933334],
#        ...,
#        [ 3.7258332,  3.7258332,  3.7258332, ...,  3.7258332,  3.7258332,
#          3.7258332],
#        [ 3.7258332,  3.7258332,  3.7258332, ...,  3.7258332,  3.7258332,
#          3.7258332],
#        [ 3.7258332,  3.7258332,  3.7258332, ...,  3.7258332,  3.7258332,
#          3.7258332]], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2021-12-31
#   * lat      (lat) float32 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float32 -179.0 -177.0 -175.0 -173.0 ... 175.0 177.0 179.0

# %%
fig, ax = plt.subplots(2, 2, figsize = (10, 10))

[ax.axis('off') for ax in fig.axes]

fig.suptitle("Temperature anomaly in the end of last four decades\n relative to 1951-1980")

def get_plot(year, i, j, k):
 
    ax = fig.add_subplot(2, 2, k, 
                         projection = ccrs.PlateCarree())
    
    ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '10m'),
                       facecolor='none', edgecolor='black')

    ax.set_extent([-150, 150, -55, 85])
    
    xr_df_sub = anomaly.loc[f"{year}-12-31"]
    
    ax.set_title(f"{year}")
    
    ax.axis("off")
    
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    
    ax.set_axis_off()
    
    ax = xr.plot.imshow(xr_df_sub,

              add_labels = True,
              vmin = -4, vmax = 4,
              cmap = "coolwarm",
               add_colorbar = False,
              interpolation = "bicubic",
              )
    
    plt.axis("off")


    
    return ax
    
ax[0, 0] = get_plot(1990, 0, 0, 1)

ax[0, 1] = get_plot(2000, 0, 1, 2)

ax[1, 0] = get_plot(2010, 0, 1, 3)


ax[1, 1] = get_plot(2020, 0, 1, 4)

# add colorbar
cax = fig.add_axes([0.92, 0.15, 0.01, 0.7]) #[left, bottom, width, height]
sm = plt.cm.ScalarMappable(cmap='coolwarm',
                           norm=plt.Normalize(vmin= -4, vmax= 4))

# fake up the array of the scalar mappable.
sm._A = []
lgd=fig.colorbar(sm, cax=cax, extend = "both"
                 ).set_label("°C", rotation=0,y=1.1, labelpad= -35)

#plt.savefig("fig.jpeg", dpi = 300)


plt.show()

# %%
year = 2020
anomaly_value = anomaly.loc[f"{year}-12-31"].mean().values

round(float(anomaly_value), 2)
# Out:
# 1.24

# %% [markdown]
# ### Temperature anomaly for the world in the end of last four decades

# %%
fig = plt.figure(figsize = (10, 10))

fig.suptitle("Global temperature anomaly in the end of last four decades\n relative to 1951-1980",
            y = 0.8)

plt.subplots_adjust(bottom = 0.3, top = 0.7, wspace=0.1, hspace= 0.25)

def get_plot(year, i, j, k):
 
    ax = fig.add_subplot(2, 2, k, 
                         projection = ccrs.PlateCarree())
    
    ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '110m'),
                       facecolor='none', edgecolor='black')

    ax.set_extent([-150, 150, -55, 85])
    
    xr_df_sub = anomaly.loc[f"{year}-12-31"]
    
    anomaly_value = anomaly.loc[f"{year}-12-31"].mean().values
    
    anomaly_value = round(float(anomaly_value), 2)

    
    ax.set_title(f"{year}: +{(anomaly_value)} [°C]")
    
    ax.axis("off")
    
    
    ax = xr.plot.imshow(xr_df_sub,

              add_labels = False,
              vmin = -4, vmax = 4,
              cmap = "coolwarm",
               add_colorbar = False,
              interpolation = "bicubic",
              )
    
    return ax
    
ax[0, 0] = get_plot(1990, 0, 0, 1)

ax[0, 1] = get_plot(2000, 0, 1, 2)

ax[1, 0] = get_plot(2010, 0, 1, 3)


ax[1, 1] = get_plot(2020, 0, 1, 4)

# add colorbar
cax = fig.add_axes([0.92, 0.3, 0.02, 0.5]) #[left, bottom, width, height]
sm = plt.cm.ScalarMappable(cmap='coolwarm',
                           norm=plt.Normalize(vmin= -4, vmax= 4))

# fake up the array of the scalar mappable.
sm._A = []
lgd=fig.colorbar(sm, cax=cax, extend = "both"
                 ).set_label("°C", rotation=0,y=1.1, labelpad= -35)

plt.savefig("../output/temperature_anomaly_for_world_in_the_end_of_last_four_decades.jpeg", dpi = 300)


plt.show()

# %% [markdown]
# ### Temperature anomaly for South Asia in the end of last four decades

# %%
fig = plt.figure(figsize = (10, 10))

fig.suptitle("Temperature anomaly for South Asia in the end of last four decades\n relative to 1951-1980",
            y = 0.8)

plt.subplots_adjust(bottom = 0.3, top = 0.7, wspace=0, hspace= 0.2)

def get_plot(year, i, j, k):
 
    ax = fig.add_subplot(2, 2, k, 
                         projection = ccrs.PlateCarree())
    
    ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '10m'),
                       facecolor='none', edgecolor='black')

    #ax.set_extent([-150, 150, -55, 85])
    ax.set_extent([60, 100, 0, 40])

    
    xr_df_sub = anomaly.loc[f"{year}-12-31"]
    
    anomaly_value = anomaly.loc[f"{year}-12-31"].mean().values
    
    anomaly_value = round(float(anomaly_value), 2)

    
    ax.set_title(f"{year}: +{(anomaly_value)} [°C]")
    
    ax.axis("off")
    
    
    ax = xr.plot.imshow(xr_df_sub,

              add_labels = False,
              vmin = -4, vmax = 4,
              cmap = "coolwarm",
               add_colorbar = False,
              interpolation = "bicubic",
              )
    
    return ax
    
ax[0, 0] = get_plot(1990, 0, 0, 1)

ax[0, 1] = get_plot(2000, 0, 1, 2)

ax[1, 0] = get_plot(2010, 0, 1, 3)


ax[1, 1] = get_plot(2020, 0, 1, 4)

# add colorbar
cax = fig.add_axes([0.92, 0.3, 0.02, 0.5]) #[left, bottom, width, height]
sm = plt.cm.ScalarMappable(cmap='coolwarm',
                           norm=plt.Normalize(vmin= -4, vmax= 4))

# fake up the array of the scalar mappable.
sm._A = []
lgd=fig.colorbar(sm, cax=cax, extend = "both", orientation = "vertical",
                 ).set_label("°C", rotation=0,y=1.1, labelpad= -35)

plt.savefig("../output/temperature_anomaly_for_south_asia_in_the_end_of_last_four_decades.jpeg", dpi = 300)


plt.show()

# %% [markdown]
# ### Animation

# %% [markdown]
# #Creating an animation for 1950-2020 and saving it as an MP4 video.
# cbar_kwargs = {
#     'orientation':'horizontal',
#     'fraction': 0.048,
#     'pad': 0.01,
#     'extend':'both'
# }
#
# fig = plt.figure(figsize=(15,15))
# fig.subplots_adjust(left=0.02, bottom=0.04, right=0.98, top=0.96)
# ax = fig.add_subplot(1,1,1, projection = ccrs.PlateCarree())
# ax.add_feature(NaturalEarthFeature('cultural', 'admin_0_countries', '10m'),
#               facecolor='none', edgecolor='black')
#
# ax.set_extent([60, 100, 0, 40])
#
# image = anomaly.isel(time=0).plot.imshow(ax=ax, add_labels=False,
#                        vmin=-4, vmax=4, cmap='coolwarm', animated=True,
#                        cbar_kwargs=cbar_kwargs, interpolation='bicubic')
#
# def animate(t):
#     date =  pd.to_datetime(anomaly.sel(time=t)['time'].values)
#     ax.set_title("Temperature Anomaly in " + str(date.year) + " [°C]")
#     ax.title.set_fontsize(18)
#     image.set_array(anomaly.sel(time=t))
#     return image
#
# ani = FuncAnimation(fig, animate, frames=anomaly['time'].values[110:], blit=False)
# ani.save("animation.gif", fps = 1)
